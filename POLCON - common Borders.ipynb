# %%
import pandas as pd
import numpy as np
import os

# %%
directory  = "/media/sony/0CA83E99A83E80EE/Chris/Bocconi/Thesis/Data_copy/Data/"

# %%
df_polcon = pd.read_excel(directory +'POLCON_2017.xlsx')

# %%
df_polcon
# Out:
#          cyear  ccode cnts_country polity_country icrg_country ctrynm    year  \
# 0        21800      2           US  United States          NaN    USA  1800.0
# 1        21801      2           US  United States          NaN    USA  1801.0
# 2        21802      2           US  United States          NaN    USA  1802.0
# 3        21803      2           US  United States          NaN    USA  1803.0
# 4        21804      2           US  United States          NaN    USA  1804.0
# 5        21805      2           US  United States          NaN    USA  1805.0
# 6        21806      2           US  United States          NaN    USA  1806.0
# 7        21807      2           US  United States          NaN    USA  1807.0
# 8        21808      2           US  United States          NaN    USA  1808.0
# 9        21809      2           US  United States          NaN    USA  1809.0
# 10       21810      2           US  United States          NaN    USA  1810.0
# ...

# %%
df_polcon.dropna(subset =['year'], inplace = True)

# %%
sub_polcon = df_polcon[['ctrynm', 'year','polconiii']]

# %%
sub_polcon.year = sub_polcon.year.astype('int64')

# %%
home_polcon = sub_polcon.rename(columns ={'ctrynm': 'home_code', 'polconiii': 'home_polcon'})
host_polcon = sub_polcon.rename(columns ={'ctrynm': 'host_code', 'polconiii': 'host_polcon'})

# %%
home_polcon.head()
# Out:
#   home_code  year  home_polcon
# 0       USA  1800     0.392401
# 1       USA  1801     0.385204
# 2       USA  1802     0.385204
# 3       USA  1803     0.301785
# 4       USA  1804     0.301785

# %%
home_polcon.tail()
# Out:
#       home_code  year  home_polcon
# 17943       WSM  2012     0.265319
# 17944       WSM  2013     0.265319
# 17945       WSM  2014     0.265319
# 17946       WSM  2015     0.265319
# 17947       WSM  2016     0.265319

# %%
host_polcon.head()
# Out:
#   host_code  year  host_polcon
# 0       USA  1800     0.392401
# 1       USA  1801     0.385204
# 2       USA  1802     0.385204
# 3       USA  1803     0.301785
# 4       USA  1804     0.301785

# %%
host_polcon.tail()
# Out:
#       host_code  year  host_polcon
# 17943       WSM  2012     0.265319
# 17944       WSM  2013     0.265319
# 17945       WSM  2014     0.265319
# 17946       WSM  2015     0.265319
# 17947       WSM  2016     0.265319

# %%
df_main = pd.read_csv(directory +'merged_COPY_FINAL8.csv')

# %%
df_main.head()
# Out:
#              home         host  year  fdi home_code host_code region  \
# 0         Albania  Afghanistan  1993  NaN       ALB       AFG    NaN
# 1         Algeria  Afghanistan  1993  NaN       DZA       AFG    NaN
# 2  American Samoa  Afghanistan  1993  NaN       ASM       AFG    NaN
# 3          Angola  Afghanistan  1993  NaN       AGO       AFG    NaN
# 4        Anguilla  Afghanistan  1993  NaN       AIA       AFG    NaN
#
#   income_group  scoreproced  minorinvest  ...  fiscal_score  invest_score  \
# 0          NaN          NaN          NaN  ...           NaN           NaN
# 1          NaN          NaN          NaN  ...           NaN           NaN
# 2          NaN          NaN          NaN  ...           NaN           NaN
# 3          NaN          NaN          NaN  ...           NaN           NaN
# 4          NaN          NaN          NaN  ...           NaN           NaN
#
#    judic_score  integrity_score   country  monthly_precip  yearly_precip  \
# ...

# %%
df_merged_home = pd.merge(df_main, home_polcon, how ='left', on=['home_code', 'year'] )

# %%
df_merged_home[df_merged_home.home_polcon ==0]
# Out:
#                                            home         host  year  fdi  \
# 7                                       Armenia  Afghanistan  1993  NaN
# 11                                   Azerbaijan  Afghanistan  1993  NaN
# 16                                      Belarus  Afghanistan  1993  NaN
# 28                            Brunei Darussalam  Afghanistan  1993  NaN
# 40                                        China  Afghanistan  1993  NaN
# 42                                      Comoros  Afghanistan  1993  NaN
# 52                                     Djibouti  Afghanistan  1993  NaN
# 59                                      Eritrea  Afghanistan  1993  NaN
# 61                                     Ethiopia  Afghanistan  1993  NaN
# 67                                        Gabon  Afghanistan  1993  NaN
# 76                                Guinea-Bissau  Afghanistan  1993  NaN
# 79                             Hong Kong, China  Afghanistan  1993  NaN
# ...

# %%
df_merged = pd.merge(df_merged_home,host_polcon, how='left', on=['host_code','year'])

# %%
df_merged.head()
# Out:
#              home         host  year  fdi home_code host_code region  \
# 0         Albania  Afghanistan  1993  NaN       ALB       AFG    NaN
# 1         Algeria  Afghanistan  1993  NaN       DZA       AFG    NaN
# 2  American Samoa  Afghanistan  1993  NaN       ASM       AFG    NaN
# 3          Angola  Afghanistan  1993  NaN       AGO       AFG    NaN
# 4        Anguilla  Afghanistan  1993  NaN       AIA       AFG    NaN
#
#   income_group  scoreproced  minorinvest  ...  judic_score  integrity_score  \
# 0          NaN          NaN          NaN  ...          NaN              NaN
# 1          NaN          NaN          NaN  ...          NaN              NaN
# 2          NaN          NaN          NaN  ...          NaN              NaN
# 3          NaN          NaN          NaN  ...          NaN              NaN
# 4          NaN          NaN          NaN  ...          NaN              NaN
#
#     country  monthly_precip  yearly_precip  precip_volatility  road_home  \
# ...

# %%
df_merged.tail()
# Out:
#                                   home      host  year  fdi home_code  \
# 1055745                        Vanuatu  Zimbabwe  2017  NaN       VUT
# 1055746  Venezuela, Bolivarian Rep. of  Zimbabwe  2017  NaN       VEN
# 1055747                       Viet Nam  Zimbabwe  2017  NaN       VNM
# 1055748                          Yemen  Zimbabwe  2017  NaN       YEM
# 1055749                         Zambia  Zimbabwe  2017  NaN       ZMB
#
#         host_code              region income_group  scoreproced  minorinvest  \
# 1055745       ZWE  Sub-Saharan Africa   Low income         80.0        53.33
# 1055746       ZWE  Sub-Saharan Africa   Low income         80.0        53.33
# 1055747       ZWE  Sub-Saharan Africa   Low income         80.0        53.33
# 1055748       ZWE  Sub-Saharan Africa   Low income         80.0        53.33
# 1055749       ZWE  Sub-Saharan Africa   Low income         80.0        53.33
#
#          ...  judic_score  integrity_score  country  monthly_precip  \
# ...

# %%
df_merged[df_merged.host_polcon ==0]
# Out:
#                                     home         host  year         fdi  \
# 0                                Albania  Afghanistan  1993         NaN
# 1                                Algeria  Afghanistan  1993         NaN
# 2                         American Samoa  Afghanistan  1993         NaN
# 3                                 Angola  Afghanistan  1993         NaN
# 4                               Anguilla  Afghanistan  1993         NaN
# 5                    Antigua and Barbuda  Afghanistan  1993         NaN
# 6                              Argentina  Afghanistan  1993         NaN
# 7                                Armenia  Afghanistan  1993         NaN
# 8                                  Aruba  Afghanistan  1993         NaN
# 9                              Australia  Afghanistan  1993         NaN
# 10                               Austria  Afghanistan  1993         NaN
# 11                            Azerbaijan  Afghanistan  1993         NaN
# ...

# %%
df_merged[(df_merged.host_polcon ==0) &(df_merged.home_polcon ==0)]
# Out:
#                                            home         host  year  \
# 7                                       Armenia  Afghanistan  1993
# 11                                   Azerbaijan  Afghanistan  1993
# 16                                      Belarus  Afghanistan  1993
# 28                            Brunei Darussalam  Afghanistan  1993
# 40                                        China  Afghanistan  1993
# 42                                      Comoros  Afghanistan  1993
# 52                                     Djibouti  Afghanistan  1993
# 59                                      Eritrea  Afghanistan  1993
# 61                                     Ethiopia  Afghanistan  1993
# 67                                        Gabon  Afghanistan  1993
# 76                                Guinea-Bissau  Afghanistan  1993
# 79                             Hong Kong, China  Afghanistan  1993
# 84                    Iran, Islamic Republic of  Afghanistan  1993
# ...

# %%
df_main = df_merged.copy()

# %%
df_contig = pd.read_csv(directory +'common_borderISO2.csv')

# %%
#df_iso = pd.read_csv(directory + 'country_code_map.csv')

# %%
#df_iso = pd.read_clipboard()

# %%
#df_iso.columns
# Out:
# Index(['Afghanistan', 'AF', 'AFG', '004'], dtype='object')

# %%
#df_iso.loc[len(df_iso)] = df_iso.columns

# %%
#df_iso.columns = ['country','iso2','iso3','numeric']

# %%
#df_iso = df_iso.sort_values('country')

# %%
#df_iso.to_csv(directory +'country_iso_code.csv', index =False)

# %%
df_iso = pd.read_csv(directory +'country_iso_code.csv')

# %%
iso2map3 = dict( zip(df_iso.iso2, df_iso.iso3) )

# %%
iso2map3
# Out:
# {'AF': 'AFG',
#  'AL': 'ALB',
#  'DZ': 'DZA',
#  'AS': 'ASM',
#  'AD': 'AND',
#  'AO': 'AGO',
#  'AI': 'AIA',
#  'AQ': 'ATA',
#  'AG': 'ATG',
#  'AR': 'ARG',
#  'AM': 'ARM',
#  'AW': 'ABW',
#  'AU': 'AUS',
#  'AT': 'AUT',
#  'AZ': 'AZE',
#  'BS': 'BHS',
#  'BH': 'BHR',
#  'BD': 'BGD',
#  'BB': 'BRB',
#  'BY': 'BLR',
#  'BE': 'BEL',
#  'BZ': 'BLZ',
#  'BJ': 'BEN',
#  'BM': 'BMU',
#  'BT': 'BTN',
#  'BO': 'BOL',
#  'BQ': 'BES',
#  'BA': 'BIH',
#  'BW': 'BWA',
#  'BV': 'BVT',
#  'BR': 'BRA',
#  'IO': 'IOT',
#  'BN': 'BRN',
#  'BG': 'BGR',
#  'BF': 'BFA',
#  'BI': 'BDI',
#  'CV': 'CPV',
#  'KH': 'KHM',
#  'CM': 'CMR',
#  'CA': 'CAN',
#  'KY': 'CYM',
#  'CF': 'CAF',
#  'TD': 'TCD',
#  'CL': 'CHL',
#  'CN': 'CHN',
#  'CX': 'CXR',
#  'CC': 'CCK',
#  'CO': 'COL',
#  'KM': 'COM',
#  'CD': 'COD',
#  'CG': 'COG',
#  'CK': 'COK',
#  'CR': 'CRI',
#  'HR': 'HRV',
#  'CU': 'CUB',
#  'CW': 'CUW',
#  'CY': 'CYP',
#  'CZ': 'CZE',
#  'CI': 'CIV',
#  'DK': 'DNK',
#  'DJ': 'DJI',
#  'DM': 'DMA',
# ...

# %%
df_contig.head()
# Out:
#   country_code          country_name country_border_code country_border_name
# 0           AD               Andorra                  FR              France
# 1           AD               Andorra                  ES               Spain
# 2           AE  United Arab Emirates                  OM                Oman
# 3           AE  United Arab Emirates                  SA        Saudi Arabia
# 4           AF           Afghanistan                  CN               China

# %%
df_contig['home_code'] = df_contig.country_code.map(iso2map3)

# %%
df_contig[df_contig.home_code.isna()]
# Out:
# Empty DataFrame
# Columns: [country_code, country_name, country_border_code, country_border_name, home_code]
# Index: []

# %%
df_contig['host_code'] = df_contig.country_border_code.map(iso2map3)

# %%
df_contig[df_contig.host_code.isna()]
# Out:
# Empty DataFrame
# Columns: [country_code, country_name, country_border_code, country_border_name, home_code, host_code]
# Index: []

# %%
df_contig['border'] =int(1)

# %%
df_contig = df_contig[['home_code','host_code','border']]

# %%
df_contig[df_contig['home_code'] == 'CHN']
# Out:
#     home_code host_code  border
# 152       CHN       AFG       1
# 153       CHN       BTN       1
# 154       CHN       HKG       1
# 155       CHN       IND       1
# 156       CHN       KAZ       1
# 157       CHN       PRK       1
# 158       CHN       KGZ       1
# 159       CHN       LAO       1
# 160       CHN       MAC       1
# 161       CHN       MNG       1
# 162       CHN       MMR       1
# 163       CHN       NPL       1
# 164       CHN       PAK       1
# 165       CHN       RUS       1
# 166       CHN       TJK       1
# 167       CHN       VNM       1

# %%
df_contig[df_contig['host_code'] == 'CHN']
# Out:
#     home_code host_code  border
# 4         AFG       CHN       1
# 96        BTN       CHN       1
# 288       HKG       CHN       1
# 318       IND       CHN       1
# 356       KGZ       CHN       1
# 366       PRK       CHN       1
# 373       KAZ       CHN       1
# 378       LAO       CHN       1
# 435       MMR       CHN       1
# 439       MNG       CHN       1
# 441       MAC       CHN       1
# 491       NPL       CHN       1
# 510       PAK       CHN       1
# 548       RUS       CHN       1
# 641       TJK       CHN       1
# 702       VNM       CHN       1

# %%
df_main.head()
# Out:
#              home         host  year  fdi home_code host_code region  \
# 0         Albania  Afghanistan  1993  NaN       ALB       AFG    NaN
# 1         Algeria  Afghanistan  1993  NaN       DZA       AFG    NaN
# 2  American Samoa  Afghanistan  1993  NaN       ASM       AFG    NaN
# 3          Angola  Afghanistan  1993  NaN       AGO       AFG    NaN
# 4        Anguilla  Afghanistan  1993  NaN       AIA       AFG    NaN
#
#   income_group  scoreproced  minorinvest  ...  judic_score  integrity_score  \
# 0          NaN          NaN          NaN  ...          NaN              NaN
# 1          NaN          NaN          NaN  ...          NaN              NaN
# 2          NaN          NaN          NaN  ...          NaN              NaN
# 3          NaN          NaN          NaN  ...          NaN              NaN
# 4          NaN          NaN          NaN  ...          NaN              NaN
#
#     country  monthly_precip  yearly_precip  precip_volatility  road_home  \
# ...

# %%
df_merge = pd.merge(df_main, df_contig, how ='left', on =['home_code','host_code'])

# %%
df_merge.border.fillna(value = 0, inplace = True)

# %%
df_merge.border = df_merge.border.astype('int64')

# %%
df_merge[df_merge.border ==1]
# Out:
#                               home         host  year  fdi home_code  \
# 40                           China  Afghanistan  1993  NaN       CHN
# 84       Iran, Islamic Republic of  Afghanistan  1993  NaN       IRN
# 137                       Pakistan  Afghanistan  1993  NaN       PAK
# 179                     Tajikistan  Afghanistan  1993  NaN       TJK
# 245                          China  Afghanistan  1994  NaN       CHN
# 289      Iran, Islamic Republic of  Afghanistan  1994  NaN       IRN
# 342                       Pakistan  Afghanistan  1994  NaN       PAK
# 384                     Tajikistan  Afghanistan  1994  NaN       TJK
# 450                          China  Afghanistan  1995  NaN       CHN
# 494      Iran, Islamic Republic of  Afghanistan  1995  NaN       IRN
# 547                       Pakistan  Afghanistan  1995  NaN       PAK
# 589                     Tajikistan  Afghanistan  1995  NaN       TJK
# 655                          China  Afghanistan  1996  NaN       CHN
# ...

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1055750 entries, 0 to 1055749
# Data columns (total 79 columns):
# home                 1055750 non-null object
# host                 1055750 non-null object
# year                 1055750 non-null int64
# fdi                  65205 non-null float64
# home_code            1055750 non-null object
# host_code            1055750 non-null object
# region               492000 non-null object
# income_group         492000 non-null object
# scoreproced          432755 non-null float64
# minorinvest          432755 non-null float64
# enfcontract          492000 non-null float64
# paytax               432755 non-null float64
# minorinvest_lag      395855 non-null float64
# diff_minorinvest     395855 non-null float64
# distance             993550 non-null float64
# uncertainty          182042 non-null float64
# home_gdp             953660 non-null float64
# host_gdp             953660 non-null float64
# ...

# %%
df_merge.to_csv(directory + 'merged_COPY_FINAL9.csv', index = False)
